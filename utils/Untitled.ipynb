# %%
import pandas as pd 
import numpy as np

# %%
root_path = "/Users/doumengge/Desktop/开课吧/开课吧/project2/data/百度题库/"

# %%
test_df = pd.read_csv("/Users/doumengge/Desktop/开课吧/开课吧/project2/data/百度题库/高中_地理/origin/地球与地图.csv")

# %%
data_path = '/Users/doumengge/Desktop/开课吧/第十一章/lecture03/kaikeba_project02/data/baidu_95.csv'
data_2 = pd.read_csv(data_path,header = None)

# %% [markdown]
# ### 提取单一文件的知识点

# %%
def preprocess_data(df):
    """
    对某一个csv文件提取知识点，删除无关列，组成新itm
    """
    item_list = df.item.tolist()
    processed_item =[]
    knowledge_list = []
    for item in item_list:
        if "知识点" not in item:
            item_str_list = item.split('\n')
            knowledge_list.append(" ")
            new_item_str = " ".join(item_str_list[1:])
            processed_item.append(new_item_str)
        else:
            item_str_list = item.split('\n')
            knowledge_list.append(item_str_list[-1].strip())
            new_item_str = " ".join(item_str_list[1:-2])
            processed_item.append(new_item_str[:-5])
    new_df = pd.DataFrame({'label':knowledge_list,'content':processed_item})
    return new_df

# %%
test_preprocess = preprocess_data(test_df)

# %%
test_preprocess.head()
# Out:
#                                              content  \
# 0  下图中等高线的高度值自北向南递减，则（   ）Aa点的海拔高度大于b点Bb点的降水流向a地C...
# 1  图a是世界某区域的年降水量和年平均等温线图，图b是其区域简图。读图可知图示区域内（   ）A...
# 2  阅读下列图文资料，完成下列各题。材料一：南美洲甲国简图材料二：L城为甲国首都，著名的游览城市...
# 3  在地形剖面图上，水平比例尺不变，垂直比例尺扩大，则（ 　 ）①更能体现地表起伏状况     ...
# 4  该图是沿我国一条经线所做的地形剖面图，横坐标表示纬度，读图后回答问题。据图判断，下列有关叙述...
#
#                                label
# 0                     [等高线地形图、地形剖面图]
# 1          [等值线图,世界洋流分布规律及其对地理环境的影响]
# 2  [等高线地形图、地形剖面图,世界洋流分布规律及其对地理环境的影响]
# 3                     [等高线地形图、地形剖面图]
# 4                     [等高线地形图、地形剖面图]

# %% [markdown]
# ### 从根目录处理文件

# %%
#从path中读取后再加
def build_data(data_path):
    subjectName_list = os.listdir(data_path)
    data_df= pd.DataFrame(columns = ['label','content'])
    for subjectName in subjectName_list:
        grade_sub = ",".join(subjectName.split('_'))
        subject_data_path = os.path.join(data_path,subjectName,"origin")
        subjectName_list2 = os.listdir(subject_data_path) #获取校标题
        for subjectName_sm in subjectName_list2:
            data_path_sub = os.path.join(subject_data_path,subjectName_sm)
            df = pd.read_csv(data_path_sub)
            new_df = preprocess_data(df)
            kn_name = subjectName_sm[:-4]
            subName = grade_sub+","+kn_name
            #print(subName)
            new_df['label'] = new_df['label'].apply(lambda x: " ".join((subName+x).split(',')))
            data_df=pd.concat((data_df,new_df))
    
    data_df.to_csv(data_path+"label_content.csv",index = None)
    return

# %%
build_data(root_path)

# %%
data = pd.read_csv(root_path+"label_content.csv")

# 29787  高中 历史 近代史中国民族资本主义的曲折发展 垄断组织的出现 第三产业的兴起和“新经济”的出...
# 29788                           高中 历史 近代史新思想的萌发 从习惯法到成文法
# 29789           高中 历史 近代史1787年宪法的颁布 《独立宣言》 凡尔赛—华盛顿体系下的和平
# 29790                          高中 历史 近代史清末民主革命风潮 辛亥革命的评价
# 29791                  高中 历史 近代史多极化趋势在曲折中发展 摆脱危机困境 曲折的发展
# 29792                    高中 历史 近代史清末民主革命风潮 第二次鸦片战争的概况及影响
# 29793  高中 历史 近代史清末民主革命风潮 国民大革命 圣彼得大教堂 中华民国的成立及《中华民国临时...
# 29794  高中 历史 近代史议会权力的确立 英国国会与国王的殊死搏斗 责任制内阁的形成 英国责任内阁制...
# 29795  高中 历史 近代史八国联军侵华战争 戊戌变法 清末民主革命风潮 甲午中日战争的概况及影响 五...
# 29796  高中 历史 近代史中国民族资本主义的曲折发展 垄断组织的出现 第三产业的兴起和“新经济”的出...
# 29797        高中 历史 近代史世界市场的拓展 走向会合的世界——世界市场雏形出现 人类迈入电气时代
# 29798  高中 历史 近代史民族区域自治制度的建立 “三个代表”重要思想 祖国统一的历史潮流 监察制度...
# 29799  高中 历史 近代史虚假“繁荣”的幻灭 东欧剧变与苏联解体 和平与动荡并存 《资政新篇》及太平...
# 29800                              高中 历史 近代史文艺复兴 启蒙运动的扩展
# 29801                             高中 历史 近代史清末民主革命风潮 抗日战争
# 29802                          高中 历史 近代史意大利资本主义萌芽 资本主义萌芽
#
# [29803 rows x 2 columns]

# %%
labels = set()
for i, v in data.iterrows():
 
    #break
    v_list = v['label'].split()
    labels.update(v_list)

# %%
len(labels)
# Out:
# 1626

# %% [markdown]
# ### 老师的数据集开始处理

# %%
data_2.head()
# Out:
#                                                    0  \
# 0                     高中 生物 分子与细胞 组成细胞的化学元素 组成细胞的化合物
# 1                           高中 生物 稳态与环境 神经调节和体液调节的比较
# 2                                高中 生物 生物技术实践 生物工程技术
# 3  高中 生物 生物技术实践 生物技术在其他方面的应用 器官移植 复等位基因 胚胎移植 基因工程...
# 4                             高中 地理 宇宙中的地球 地球运动的地理意义
#
#                                                    1
# 0  菠菜从土壤中吸收的氮元素可以用来合成（）A.淀粉和纤维素B.葡萄糖和DNAC.核酸和蛋白质D...
# 1  下列有关生物体内信息传递的叙述，正确的是（）A下丘脑分泌的促甲状腺激素释放激素，可作用于甲状...
# 2  从自然菌样筛选较理想生产菌种的一般步骤是：采集菌样→富集培养→纯种分离→性能测定．1.不同微...
# 3  目前，精子载体法逐渐成为具有诱惑力的制备转基因动物方法之一，该方法以精子作为外源基因的载体，...
# 4   某人想乘普通飞机在一年中连续过两次生日，你认为应穿越（）A赤道B两级C本初子午线D国际日期变更线

# %% [markdown]
# 1. clean_sentence:去除无关词
# 2. load_stopwords
# 3.d
